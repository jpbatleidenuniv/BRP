# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Read catalogues and show columns

# %%
hunt = pd.read_csv('../data/hunt_catalogue.csv')
kharchenko = pd.read_csv('../data/kharchenko_catalogue.csv')
hunt_xm = pd.read_csv('../data/hunt_crossmatch.csv')

print(hunt.columns)
print(kharchenko.columns)
print(hunt_xm.columns)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 hunt = pd.read_csv('../data/hunt_catalogue.csv')
#       2 kharchenko = pd.read_csv('../data/kharchenko_catalogue.csv')
#       3 hunt_xm = pd.read_csv('../data/hunt_crossmatch.csv')
#
# File c:\Users\johan\Anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\johan\Anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File c:\Users\johan\Anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\johan\Anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File c:\Users\johan\Anaconda3\Lib\site-packages\pandas\io\common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/hunt_catalogue.csv'

# %% [markdown]
# ### Show Hunt catalogue

# %%
hunt
# Out:
#       recno             Name    ID  \
# 0         1         1636-283     0
# 1         2        ADS_16795     1
# 2         3  AH03_J0748+26.9     2
# 3         4           ASCC_5     3
# 4         5           ASCC_6     4
# ...     ...              ...   ...
# 7162   7163       vdBergh_85  7162
# 7163   7164       vdBergh_92  7163
# 7164   7165      vdBergh_113  7164
# 7165   7166      vdBergh_130  7165
# 7166   7167      vdBergh_152  7166
#
#                                                AllNames Type        CST    N  \
# 0               1636-283,C1636-283,ESO_452-11,MWSC_2436    o   8.106141   38
# 1                                      ADS_16795,AR_Cas    o   6.832199   41
# 2     AH03_J0748+26.9,AH03_J0748-26.9,AH03_J0748_26....    o  11.585524   68
# 3                                        ASCC_5,MWSC_93    o   8.316422   25
# 4                            ASCC_6,MWSC_141,Theia_2326    o  19.258570  209
# ...                                                 ...  ...        ...  ...
# 7162                                         vdBergh_85    o  11.847597  105
# 7163                                         vdBergh_92    o  21.995554  345
# 7164                       UBC_1005,UFMG_84,vdBergh_113    o  15.770199  163
# 7165                                        vdBergh_130    o  11.430369  162
# 7166                          OCSN_37,PTB_3,vdBergh_152    o   7.825618   25
#
#            CSTt   Nt     RA_ICRS  ...      MOD16      MOD50      MOD84  \
# 0      8.794951   32  249.855743  ...  13.771433  14.001991  14.187698
# 1      6.832199   41  352.592165  ...   6.491674   6.649982   6.814627
# 2     11.781309   66  117.155887  ...  13.326923  13.521471  13.707494
# 3      8.316422   25   14.469082  ...  11.046813  11.212086  11.370137
# 4     19.258570  209   26.842159  ...  10.703223  10.890650  11.055896
# ...         ...  ...         ...  ...        ...        ...        ...
# 7162  11.847597  105  101.720134  ...  10.931759  11.125109  11.264691
# 7163  21.995554  345  106.036502  ...  10.040602  10.191625  10.338547
# 7164  15.829355  152  272.165492  ...  10.599004  10.748435  10.885481
# 7165  12.842494  131  304.517447  ...  10.996379  11.143586  11.296269
# 7166   7.825618   25  333.362827  ...   7.602933   7.762949   7.912142
#
#       minClSize  isMerged  isGMMMemb  NXmatches  XmatchType    _RA.icrs  \
# 0            20         0          0          2         1:m  249.855750
# 1            40         0          0          1         1:1  352.592006
# 2            10         0          0          2         1:m  117.155899
# 3            10         0          0          1         1:1   14.469101
# 4            80         0          0          2         1:m   26.842166
# ...         ...       ...        ...        ...         ...         ...
# 7162         80         0          0          1         1:1  101.720138
# 7163         40         0          0          1         m:1  106.036522
# 7164         80         0          0          3         1:m  272.165496
# 7165         80         0          0          1         1:1  304.517467
# 7166         20         0          0          3         1:m  333.362758
#
#        _DE.icrs
# 0    -28.399165
# 1     58.553401
# 2    -26.972694
# 3     55.829182
# 4     57.738606
# ...         ...
# 7162   1.324254
# 7163 -11.442345
# 7164 -21.441471
# 7165  39.366669
# 7166  70.176287
#
# [7167 rows x 67 columns]

# %% [markdown]
# ## Show catalogues available in Hunt's crossmatch table

# %%
set(hunt_xm['SourceCat'])
# Out:
# {'Anders+22',
#  'Bastian+19',
#  'Bica+08',
#  'Bica+18',
#  'Cantat-Gaudin+20',
#  'Casado+21',
#  'Casado+23',
#  'Castro-Ginard+20',
#  'Castro-Ginard+22',
#  'Chi+22',
#  'Chi+23',
#  'Dias+02',
#  'Ferreira+19',
#  'Ferreira+20',
#  'Ferreira+21',
#  'Hao+20',
#  'Hao+22',
#  'He+21',
#  'He+22a',
#  'He+22b',
#  'He+22c',
#  'Hunt+21',
#  'Jaehnig+21',
#  'Kharchenko+13',
#  'Kounkel+20',
#  'Li+22',
#  'Li+23',
#  'Liu+19',
#  'Qin+20',
#  'Qin+23',
#  'Santos-Silva+21',
#  'Sim+19',
#  'Tian+20',
#  'Vasiliev+21',
#  'Zari+18'}

# %% [markdown]
# ### Get only the objects crossmatched to Kharchenko's catalogue

# %%
kharchenko_xm = hunt_xm.query('SourceCat == "Kharchenko+13"')
kharchenko_xm
# Out:
#        recno    ID          NameLit      SourceCat       TypeSourceCat  \
# 0          1     0         1636-283  Kharchenko+13           hipparcos
# 1          2     0         1636-283  Kharchenko+13            position
# 4          5     0       2MASS-GC02  Kharchenko+13  position,hipparcos
# 10        11     0  AH03_J0822+36.4  Kharchenko+13  position,hipparcos
# 24        25     0           ASCC_1  Kharchenko+13  position,hipparcos
# ...      ...   ...              ...            ...                 ...
# 29937  29938  7161       vdBergh_83  Kharchenko+13            position
# 29938  29939  7162       vdBergh_85  Kharchenko+13           hipparcos
# 29940  29941  7162       vdBergh_85  Kharchenko+13            position
# 29942  29943  7163       vdBergh_92  Kharchenko+13            position
# 29944  29945  3217       vdBergh_92  Kharchenko+13            position
#
#             Sep  SepTidal  SepTidalLit  SepTidalData  pmRASep  pmRASigma  \
# 0      0.000298  0.002366     0.003970      0.002366   3.4450   0.662721
# 1      0.000298  0.002366     0.003970      0.002366      NaN        NaN
# 4           NaN       NaN          NaN           NaN      NaN        NaN
# 10          NaN       NaN          NaN           NaN      NaN        NaN
# 24          NaN       NaN          NaN           NaN      NaN        NaN
# ...         ...       ...          ...           ...      ...        ...
# 29937  0.114700  0.154470     0.955673      0.154470      NaN        NaN
# 29938  0.009891  0.024375     0.076088      0.024375   0.2275   0.043188
# 29940  0.009891  0.024375     0.076088      0.024375      NaN        NaN
# 29942  0.089140  0.185433     0.356566      0.185433      NaN        NaN
# 29944  0.149400  0.210250     0.597759      0.210250      NaN        NaN
#
#        pmDESep  pmDESigma   PlxSep  PlxSigma  maxSigma  meanSigma
# 0        1.696     0.3213  0.04456    0.0000     0.663     0.3280
# 1          NaN        NaN      NaN       NaN       NaN        NaN
# 4          NaN        NaN      NaN       NaN       NaN        NaN
# 10         NaN        NaN      NaN       NaN       NaN        NaN
# 24         NaN        NaN      NaN       NaN       NaN        NaN
# ...        ...        ...      ...       ...       ...        ...
# 29937      NaN        NaN      NaN       NaN       NaN        NaN
# 29938    1.905     0.4513  0.06676    0.2839     0.451     0.2595
# 29940      NaN        NaN      NaN       NaN       NaN        NaN
# 29942      NaN        NaN      NaN       NaN       NaN        NaN
# 29944      NaN        NaN      NaN       NaN       NaN        NaN
#
# [4257 rows x 17 columns]

# %% [markdown]
# ### Get rid of the not crossmatched objects (Sep = Nan)

# %%
kharchenko_xm = kharchenko_xm.dropna(subset = ['Sep'])
kharchenko_xm
# Out:
#        recno    ID     NameLit      SourceCat TypeSourceCat       Sep  \
# 0          1     0    1636-283  Kharchenko+13     hipparcos  0.000298
# 1          2     0    1636-283  Kharchenko+13      position  0.000298
# 26        27   114     ASCC_10  Kharchenko+13     hipparcos  0.164400
# 28        29   114     ASCC_10  Kharchenko+13      position  0.164400
# 29        30    50    ASCC_100  Kharchenko+13      position  0.025990
# ...      ...   ...         ...            ...           ...       ...
# 29937  29938  7161  vdBergh_83  Kharchenko+13      position  0.114700
# 29938  29939  7162  vdBergh_85  Kharchenko+13     hipparcos  0.009891
# 29940  29941  7162  vdBergh_85  Kharchenko+13      position  0.009891
# 29942  29943  7163  vdBergh_92  Kharchenko+13      position  0.089140
# 29944  29945  3217  vdBergh_92  Kharchenko+13      position  0.149400
#
#        SepTidal  SepTidalLit  SepTidalData  pmRASep  pmRASigma  pmDESep  \
# 0      0.002366     0.003970      0.002366   3.4450   0.662721   1.6960
# 1      0.002366     0.003970      0.002366      NaN        NaN      NaN
# 26     0.031312     0.310144      0.031312   1.0470   0.274158   0.2413
# 28     0.031312     0.310144      0.031312      NaN        NaN      NaN
# 29     0.008916     0.071212      0.008916      NaN        NaN      NaN
# ...         ...          ...           ...      ...        ...      ...
# 29937  0.154470     0.955673      0.154470      NaN        NaN      NaN
# 29938  0.024375     0.076088      0.024375   0.2275   0.043188   1.9050
# 29940  0.024375     0.076088      0.024375      NaN        NaN      NaN
# 29942  0.185433     0.356566      0.185433      NaN        NaN      NaN
# 29944  0.210250     0.597759      0.210250      NaN        NaN      NaN
#
#        pmDESigma   PlxSep  PlxSigma  maxSigma  meanSigma
# 0        0.32130  0.04456    0.0000     0.663     0.3280
# 1            NaN      NaN       NaN       NaN        NaN
# 26       0.05259  0.11460    0.4058     0.406     0.2442
# 28           NaN      NaN       NaN       NaN        NaN
# 29           NaN      NaN       NaN       NaN        NaN
# ...          ...      ...       ...       ...        ...
# 29937        NaN      NaN       NaN       NaN        NaN
# 29938    0.45130  0.06676    0.2839     0.451     0.2595
# 29940        NaN      NaN       NaN       NaN        NaN
# 29942        NaN      NaN       NaN       NaN        NaN
# 29944        NaN      NaN       NaN       NaN        NaN
#
# [2859 rows x 17 columns]

# %% [markdown]
# ### Show how many unique clusters in Hunt are crossmatched (unique ID)

# %%
len(np.unique(kharchenko_xm['ID']))
# Out:
# 1705

# %% [markdown]
# ### Count how many of these belong to the right type ('o')

# %%
c = 0

for i in np.unique(kharchenko_xm['ID'])[1:2]:
    if i > 7166: continue
    type_object = hunt.query('ID == @i')['Type'][hunt.query('ID == @i').index[0]]
    if type_object == 'o': c = c + 1

print(c)
# Out:
# 1

# %% [markdown]
# ### Count how many of these belong to the right type in Kharchenko's catalogue (not 'g' -> globular cluster)

# %%
kharchenko_names_oc = np.array(kharchenko.query('Type != "g"')['Name'],dtype = object)

# %%
c = 0

for i in np.unique(kharchenko_xm['ID']):
    if i > 7166: continue
    type_object = hunt.query('ID == @i')['Type'][hunt.query('ID == @i').index[0]]
    if type_object == 'o': 
        for j in np.unique(kharchenko_xm.query('ID == @i')['NameLit'])[0:1]:
            if j in kharchenko_names_oc:
                c = c + 1

print(c)
# Out:
# 1485

# %% [markdown]
# ### It can still be that the name we were checking was in the allNames column, check this

# %%
c = 0
cc = 0

for i in np.unique(kharchenko_xm['ID']):
    if i > 7166: continue
    type_object = hunt.query('ID == @i')['Type'][hunt.query('ID == @i').index[0]]
    if type_object == 'o': 
        if hunt.query('ID == @i')['AllNames'].isnull().values[0]: continue
        for j in list(hunt.query('ID == @i')['AllNames'])[0].split(','):
            if j in kharchenko_names_oc:
                c = c + 1

print(c)
# Out:
# 1513
